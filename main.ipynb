# %%
#Installing dependencies
import torch
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
Image_path = 'adobe.png'
reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(Image_path)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# [([[np.int32(7), np.int32(7)],
#    [np.int32(121), np.int32(7)],
#    [np.int32(121), np.int32(23)],
#    [np.int32(7), np.int32(23)]],
#   'Adobe; the Adobe',
#   np.float64(0.8024744513736023)),
#  ([[np.int32(159), np.int32(6)],
#    [np.int32(595), np.int32(6)],
#    [np.int32(595), np.int32(26)],
#    [np.int32(159), np.int32(26)]],
#   'Acrobat; the Acrobat logo, Acrobat Capture, Adobe Garamond, Adobe',
#   np.float64(0.5892085908939603)),
#  ([[np.int32(7), np.int32(23)],
#    [np.int32(595), np.int32(23)],
#    [np.int32(595), np.int32(43)],
#    [np.int32(7), np.int32(43)]],
#   'Intelligent Document Platform, Adobe PDE Adobe Reader; Adobe Solutions Network; Aldus; Dis-',
#   np.float64(0.7041671646965779)),
#  ([[np.int32(7), np.int32(41)],
#    [np.int32(593), np.int32(41)],
#    [np.int32(593), np.int32(59)],
#    [np.int32(7), np.int32(59)]],
#   'tiller; ePaper; Extreme, FrameMaker; Illustrator; InDesign, Minion, Myriad, PageMaker; Photo-',
#   np.float64(0.6260687718737877)),
#  ([[np.int32(4), np.int32(54)],
#    [np.int32(596), np.int32(54)],
#    [np.int32(596), np.int32(78)],
#    [np.int32(4), np.int32(78)]],
#   "shop; Poetica, PostScript, and XMP are either registered trademarks' or trademarks of Adobe",
#   np.float64(0.5885323059730274)),
#  ([[np.int32(5), np.int32(73)],
#    [np.int32(415), np.int32(73)],
#    [np.int32(415), np.int32(93)],
#    [np.int32(5), np.int32(93)]],
#   'Systems Incorporated in the United States andlor other countries',
#   np.float64(0.7682313822089197)),
#  ([[np.int32(421), np.int32(73)],
#    [np.int32(595), np.int32(73)],
#    [np.int32(595), np.int32(89)],
#    [np.int32(421), np.int32(89)]],
#   'Microsoft and Windows are',
#   np.float64(0.5335407005157118)),
#  ([[np.int32(7), np.int32(90)],
#    [np.int32(595), np.int32(90)],
#    [np.int32(595), np.int32(111)],
#    [np.int32(7), np.int32(111)]],
#   'either registered trademarks or trademarks of Microsoft Corporation in the United States and/or',
#   np.float64(0.8044112976303864)),
#  ([[np.int32(7), np.int32(106)],
#    [np.int32(379), np.int32(106)],
#    [np.int32(379), np.int32(125)],
#    [np.int32(7), np.int32(125)]],
#   'other countries Apple, Mac, Macintosh, and Power Macintosh',
#   np.float64(0.6758677276554945)),
#  ([[np.int32(403), np.int32(107)],
#    [np.int32(595), np.int32(107)],
#    [np.int32(595), np.int32(125)],
#    [np.int32(403), np.int32(125)]],
#   'trademarks of Apple Computer;',
#   np.float64(0.9197531017929665)),
#  ([[np.int32(37), np.int32(125)],
#    [np.int32(403), np.int32(125)],
#    [np.int32(403), np.int32(143)],
#    [np.int32(37), np.int32(143)]],
#   'registered in the United States and other countries IBM is',
#   np.float64(0.6882889392965573)),
#  ([[np.int32(415), np.int32(125)],
#    [np.int32(595), np.int32(125)],
#    [np.int32(595), np.int32(143)],
#    [np.int32(415), np.int32(143)]],
#   'registered trademark of IBM',
#   np.float64(0.8297231490389981)),
#  ([[np.int32(7), np.int32(141)],
#    [np.int32(257), np.int32(141)],
#    [np.int32(257), np.int32(159)],
#    [np.int32(7), np.int32(159)]],
#   'Corporation in the United States. Sun is',
#   np.float64(0.8209158885207871)),
#  ([[np.int32(269), np.int32(141)],
#    [np.int32(355), np.int32(141)],
#    [np.int32(355), np.int32(157)],
#    [np.int32(269), np.int32(157)]],
#   'trademark or',
#   np.float64(0.9279990781162326)),
#  ([[np.int32(353), np.int32(139)],
#    [np.int32(594), np.int32(139)],
#    [np.int32(594), np.int32(163)],
#    [np.int32(353), np.int32(163)]],
#   'registered trademark of Sun Microsys-',
#   np.float64(0.8741333152851216)),
#  ([[np.int32(7), np.int32(155)],
#    [np.int32(373), np.int32(155)],
#    [np.int32(373), np.int32(173)],
#    [np.int32(7), np.int32(173)]],
#   'tems, Inc. in the United States and other countries. UNIX is',
#   np.float64(0.6423660530708972)),
#  ([[np.int32(381), np.int32(154)],
#    [np.int32(596), np.int32(154)],
#    [np.int32(596), np.int32(178)],
#    [np.int32(381), np.int32(178)]],
#   'registered trademark of The Open',
#   np.float64(0.8554778120463103)),
#  ([[np.int32(6), np.int32(173)],
#    [np.int32(595), np.int32(173)],
#    [np.int32(595), np.int32(193)],
#    [np.int32(6), np.int32(193)]],
#   'Group: SVG is a trademark of the World Wide Web Consortium; marks of the W3C are registered',
#   np.float64(0.6887015505087933)),
#  ([[np.int32(5), np.int32(191)],
#    [np.int32(595), np.int32(191)],
#    [np.int32(595), np.int32(209)],
#    [np.int32(5), np.int32(209)]],
#   'and held by its hostlinstitutionsJMIT; INRIA and Keio: Helvetica and Times are registered trade-',
#   np.float64(0.47926508310252425)),
#  ([[np.int32(7), np.int32(207)],
#    [np.int32(369), np.int32(207)],
#    [np.int32(369), np.int32(225)],
#    [np.int32(7), np.int32(225)]],
#   'marks of Linotype-Hell AG andlor its subsidiaries. Arial and',
#   np.float64(0.8456297432218768)),
#  ([[np.int32(409), np.int32(207)],
#    [np.int32(597), np.int32(207)],
#    [np.int32(597), np.int32(223)],
#    [np.int32(409), np.int32(223)]],
#   'New Roman are trademarks of',
#   np.float64(0.9145985136018187)),
#  ([[np.int32(7), np.int32(225)],
#    [np.int32(177), np.int32(225)],
#    [np.int32(177), np.int32(243)],
#    [np.int32(7), np.int32(243)]],
#   'The Monotype Corporation',
#   np.float64(0.7619510059501672)),
#  ([[np.int32(175), np.int32(220)],
#    [np.int32(304), np.int32(220)],
#    [np.int32(304), np.int32(245)],
#    [np.int32(175), np.int32(245)]],
#   'registered in the US.',
#   np.float64(0.7771571253358207)),
#  ([[np.int32(307), np.int32(223)],
#    [np.int32(595), np.int32(223)],
#    [np.int32(595), np.int32(243)],
#    [np.int32(307), np.int32(243)]],
#   'Patent and Trademark Office and may be regis-',
#   np.float64(0.8240034245137324)),
#  ([[np.int32(7), np.int32(241)],
#    [np.int32(355), np.int32(241)],
#    [np.int32(355), np.int32(259)],
#    [np.int32(7), np.int32(259)]],
#   'tered in certain other jurisdictions. ITC Zapf Dingbats is',
#   np.float64(0.7941580540201748)),
#  ([[np.int32(364), np.int32(240)],
#    [np.int32(595), np.int32(240)],
#    [np.int32(595), np.int32(259)],
#    [np.int32(364), np.int32(259)]],
#   'registered trademark of International',
#   np.float64(0.8624641092558524)),
#  ([[np.int32(7), np.int32(257)],
#    [np.int32(245), np.int32(257)],
#    [np.int32(245), np.int32(275)],
#    [np.int32(7), np.int32(275)]],
#   'Typeface Corporation. Ryumin Light is',
#   np.float64(0.8431933871423228)),
#  ([[np.int32(255), np.int32(257)],
#    [np.int32(595), np.int32(257)],
#    [np.int32(595), np.int32(273)],
#    [np.int32(255), np.int32(273)]],
#   'trademark of Morisawa & Co , Ltd All other trademarks',
#   np.float64(0.7671316027188971)),
#  ([[np.int32(27), np.int32(273)],
#    [np.int32(263), np.int32(273)],
#    [np.int32(263), np.int32(292)],
#    [np.int32(27), np.int32(292)]],
#   'the property of their respective owners_',
#   np.float64(0.8610264485729595)),
#  ([[np.float64(123.06850713433475), np.float64(5.230163555236035)],
#    [np.float64(154.88485549096248), np.float64(10.331180309658471)],
#    [np.float64(151.93149286566523), np.float64(27.769836444763964)],
#    [np.float64(120.1151445090375), np.float64(22.66881969034153)]],
#   'logo;',
#   np.float64(0.5261193303197802)),
#  ([[np.float64(377.14250707428744), np.float64(110.48550424457247)],
#    [np.float64(399.84548890303097), np.float64(107.46600700861202)],
#    [np.float64(400.85749292571256), np.float64(117.51449575542753)],
#    [np.float64(379.15451109696903), np.float64(120.53399299138798)]],
#   'are',
#   np.float64(0.4866004149420251)),
#  ([[np.float64(7.47000105999682), np.float64(123.15200169599491)],
#    [np.float64(37.95170861776055), np.float64(126.69299722007725)],
#    [np.float64(35.52999894000318), np.float64(140.84799830400507)],
#    [np.float64(5.048291382239449), np.float64(137.30700277992275)]],
#   'Inc ',
#   np.float64(0.2520867586135864)),
#  ([[np.float64(371.4929798734366), np.float64(206.13806578484224)],
#    [np.float64(409.97439119569464), np.float64(210.77514049330125)],
#    [np.float64(407.5070201265634), np.float64(224.86193421515776)],
#    [np.float64(369.02560880430536), np.float64(220.22485950669875)]],
#   'Times',
#   np.float64(0.8852659026323725))]

# %%
import ssl
import urllib.request

ssl._create_default_https_context = ssl._create_unverified_context

# Your download logic here

# %%
image_path  = 'text.png'
reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(image_path)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [([[np.int32(4), np.int32(6)],
#    [np.int32(218), np.int32(6)],
#    [np.int32(218), np.int32(36)],
#    [np.int32(4), np.int32(36)]],
#   'It was the best of',
#   np.float64(0.9844718446720789)),
#  ([[np.int32(3), np.int32(40)],
#    [np.int32(276), np.int32(40)],
#    [np.int32(276), np.int32(70)],
#    [np.int32(3), np.int32(70)]],
#   'times, it was the worst',
#   np.float64(0.8060882850369808)),
#  ([[np.int32(3), np.int32(73)],
#    [np.int32(281), np.int32(73)],
#    [np.int32(281), np.int32(109)],
#    [np.int32(3), np.int32(109)]],
#   'of times, it was the age',
#   np.float64(0.9604629077557313)),
#  ([[np.int32(3), np.int32(103)],
#    [np.int32(263), np.int32(103)],
#    [np.int32(263), np.int32(139)],
#    [np.int32(3), np.int32(139)]],
#   'of wisdom; it was the',
#   np.float64(0.8532379655583799)),
#  ([[np.int32(3), np.int32(137)],
#    [np.int32(229), np.int32(137)],
#    [np.int32(229), np.int32(175)],
#    [np.int32(3), np.int32(175)]],
#   'age of foolishness_',
#   np.float64(0.9649929608521849))]

# %%
img = cv2.imread(image_path)
for detection in result:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]
    font = cv2.FONT_HERSHEY_SIMPLEX
    img = cv2.rectangle(img, top_left, bottom_right, (0,255,0), 5)
    img = cv2.putText(img, text, top_left, font, 2, (255,255,255), 2, cv2.LINE_AA)
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
